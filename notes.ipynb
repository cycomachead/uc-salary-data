# %%
# Start writing code here...

# %% [markdown]
# # Notes and References
#
# September 18, 2021
#
# UC Headcount Dashboard https://www.universityofcalifornia.edu/infocenter/uc-employee-headcount
# FTE Data: https://www.universityofcalifornia.edu/infocenter/employee-fte
#
# 1777/4220 Lecturers are "full time", > 75% appt. -- 42%
#
#
# https://docs.google.com/spreadsheets/d/1QhFceXzOC7N_alky5q-D9KnBunmnAZtmhRR4ItQYugc/edit#gid=467647470
#
# Title Codes: https://accountability.universityofcalifornia.edu/glossary.html#table3

# %% [markdown]
# ## Title categories (September 2026)
#
# See `docs/title-categories.md` for the category scheme, data sources, and how the `data/title_categories.csv` / `data/title_crosswalk.csv` files are built and synced with the Google Sheet (`categorize-titles.py`, `sync-title-sheet.py`, `build-db.py --titles-only`).
#
# Reference material pulled from UC pages is in `data/reference/`:
#
# * `ucop_academic_titles.csv` - UCOP academic title codes with Class Title Outline (CTO), parsed from https://www.ucop.edu/academic-personnel-programs/compensation/academic-ctos-titles-and-title-codes/
# * `uc_headcount_dashboard.csv` - April headcounts by personnel program / CTO group from the UC employee headcount dashboard (https://www.universityofcalifornia.edu/about-uc/information-center/uc-employee-headcount)
